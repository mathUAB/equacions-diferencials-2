# %%
var(' y c')
# Out:
# (y, c)

# %%
f=x*(1-c*x^2)/(1+c*x^2)

# %%
df=f.diff(x).simplify_full()
show(df)
# Out:
# -(c^2*x^4 + 4*c*x^2 - 1)/(c^2*x^4 + 2*c*x^2 + 1)

# %%
show((f*x-df*x^2).simplify_full())
# Out:
# 4*c*x^4/(c^2*x^4 + 2*c*x^2 + 1)

# %%
def div(p,q):
    dp=diff(p,x).simplify_full()
    dq=diff(q,y).simplify_full()
    return (dp+dq).simplify_full()

# %%
p=x*(1-x-y)
q=y*(1-x-y)

# %%
var('a b')
# Out:
# (a, b)

# %%
B=y^-3

# %%
div(p*B,q*B).factor()
# Out:
# -1/y^3

# %%
p=y-f
q=-x

# %%
plot_vector_field(((p/sqrt(p^2+q^2)).subs(c=1),(q/sqrt(p^2+q^2)).subs(c=1)),(x,-1,1),(y,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
(p^2+q^2).simplify_full()
# Out:
# (2*c^2*x^6 + (c^2*x^4 + 2*c*x^2 + 1)*y^2 + 2*x^2 + 2*(c^2*x^5 - x)*y)/(c^2*x^4 + 2*c*x^2 + 1)
